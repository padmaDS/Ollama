# %%
# !pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in c:\users\padma\anaconda3\lib\site-packages (from ollama) (0.27.0)
# Collecting pydantic>=2.9 (from ollama)
#   Using cached pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Requirement already satisfied: anyio in c:\users\padma\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\padma\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\padma\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (1.0.2)
# Requirement already satisfied: idna in c:\users\padma\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (3.7)
# Requirement already satisfied: sniffio in c:\users\padma\anaconda3\lib\site-packages (from httpx>=0.27->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\padma\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\padma\anaconda3\lib\site-packages (from pydantic>=2.9->ollama) (0.6.0)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.9->ollama)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\padma\anaconda3\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.9->ollama)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Using cached pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.9 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 1.8 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.1 MB/s eta 0:00:00
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, pydantic, ollama
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
# Successfully installed ollama-0.6.1 pydantic-2.12.4 pydantic-core-2.41.5 typing-inspection-0.4.2

# %%
import ollama

# %%
import ollama

response = ollama.generate(
    model="llama3.2:1b",
    prompt="Hi, how are you?"
)

print(response["response"])
# Out:
# I'm doing well, thank you for asking. Is there something I can help you with or would you like to chat?

# %%
import ollama

response = ollama.generate(
    model="llama3.2:1b",
    prompt="what is the capital of India?"
)

print(response["response"])
# Out:
# The capital of India is New Delhi.

# %%
import ollama

response = ollama.generate(
    model="llama3.2:1b",
    prompt="What is reinforcement Learning?"
)

print(response["response"])
# Out:
# Reinforcement learning (RL) is a type of machine learning that involves training an agent to take actions in an environment and receive rewards or penalties for its actions. The goal of RL is to learn how to make decisions that maximize the cumulative reward over time.
#
# In traditional machine learning, a model is trained on a dataset where the goal is to predict a specific output based on input features. In reinforcement learning, the agent learns by interacting with an environment and receiving rewards or penalties for its actions.
#
# The key characteristics of RL are:
#
# 1. **Interleaving**: The agent interacts with the environment multiple times, each time taking a different action.
# 2. **Feedback loop**: The agent receives feedback on its performance, which is used to update its policy (or decision-making strategy).
# 3. **Optimization objective**: The goal is to maximize the cumulative reward over time.
#
# There are several types of reinforcement learning algorithms, including:
#
# 1. **Q-learning**: This algorithm learns a value function Q(s, a) that estimates the expected return for taking action a in state s.
# 2. **Deep Q-Networks (DQN)**: A type of DQN that uses a neural network to estimate the value function Q(s, a).
# 3. **Policy Gradient Methods**: These methods learn a policy directly instead of estimating a value function.
# 4. **Actor-Critic Methods**: These methods combine policy gradient methods with value function estimation.
#
# Reinforcement learning has many applications, including:
#
# 1. **Game playing**: RL can be used to train agents to play games like chess, Go, or poker.
# 2. **Robotics**: RL can be used to control robots that need to learn how to perform tasks in complex environments.
# 3. **Autonomous vehicles**: RL can be used to teach autonomous vehicles to navigate and make decisions in complex scenarios.
# 4. **Recommendation systems**: RL can be used to recommend products or services based on user behavior.
#
# Overall, reinforcement learning is a powerful tool for learning from experience and making decisions in complex environments.

# %%
response = ollama.generate(
    model="llama3.2:1b",
    prompt="What is Machine Learning?"
)

print(response["response"])
# Out:
# Machine learning (ML) is a subset of artificial intelligence (AI) that involves training algorithms to learn from data, make predictions or decisions without being explicitly programmed. In other words, ML allows computers to improve their performance on a task without being explicitly instructed how to do it.
#
# The basic idea behind machine learning is to use statistical models and algorithms to identify patterns in data, make predictions, and classify objects into categories. This process involves several key steps:
#
# 1. **Data collection**: Gathering a large dataset relevant to the problem you want to solve.
# 2. **Data preprocessing**: Cleaning, transforming, and preparing the data for modeling.
# 3. **Model training**: Training an algorithm on the preprocessed data to learn patterns and relationships.
# 4. **Model evaluation**: Testing the trained model on new, unseen data to evaluate its performance.
#
# There are several types of machine learning, including:
#
# 1. **Supervised learning**: The algorithm learns from labeled data, where the correct output is already known.
# 2. **Unsupervised learning**: The algorithm discovers patterns in unlabeled data without prior knowledge.
# 3. **Reinforcement learning**: The algorithm learns through trial and error by interacting with an environment.
#
# Machine learning has many applications across industries, including:
#
# 1. **Image recognition**: Facial recognition, object detection, self-driving cars
# 2. **Natural language processing**: Sentiment analysis, language translation, chatbots
# 3. **Predictive maintenance**: Predicting equipment failures based on sensor data
# 4. **Recommendation systems**: Personalized product recommendations
#
# Machine learning has many benefits, including:
#
# 1. **Improved accuracy**: Algorithms can learn from data and improve over time.
# 2. **Increased efficiency**: Automating tasks and reducing the need for human intervention.
# 3. **Personalization**: Tailoring experiences to individual preferences.
#
# However, machine learning also raises concerns about:
#
# 1. **Bias and fairness**: Algorithms may perpetuate existing biases if not designed carefully.
# 2. **Data quality**: Poor data quality can lead to inaccurate models.
# 3. **Job displacement**: Machine learning automation may displace certain jobs.
#
# Overall, machine learning is a powerful tool that has the potential to transform various aspects of our lives.
